# %%
1+1
# Out:
# 2

# %%
1+1
# Out:
# 2

# %% [raw]
# str()

# %%
"Hi"
# Out:
# 'Hi'

# %%
##my comment on this piece of code
from math import sqrt

# %%
s='hello'

# %%
s
# Out:
# 'hello'

# %%
s.upper()
# Out:
# 'HELLO'

# %%
s.count
# Out:
# <function str.count>

# %%
s.capitalize()
# Out:
# 'Hello'

# %% [markdown]
# #Add Two numbers
# ##Problem
